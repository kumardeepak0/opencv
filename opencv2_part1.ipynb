# %%
import cv2

# %%
# first import thr package
# if you get the error : than install the package

# !pip install opencv-python
# when you want install through cmd: remove ! mark
#                                   : pip install <package_name>
# if you want install in jupyter notebook: add the ! mark and run
#                                        : !pip install <package_name>

# %% [markdown]
# **Method:-1**
#
# - using openCV method
# - when you read image, it will open a new window
# - and image will display on the window
# - if you want to close the window press :0

# %%
import os
os.getcwd()
image=cv2.imread(r'Benjamin-Franklin.webp')
image
# Out:
# array([[[19, 12, 13],
#         [19, 12, 13],
#         [19, 12, 13],
#         ...,
#         [16, 20, 49],
#         [14, 17, 46],
#         [11, 15, 44]],
#
#        [[19, 12, 13],
#         [19, 12, 13],
#         [19, 12, 13],
#         ...,
#         [16, 20, 49],
#         [14, 17, 46],
#         [11, 15, 44]],
#
#        [[19, 12, 13],
#         [19, 12, 13],
#         [19, 12, 13],
#         ...,
#         [16, 20, 49],
#         [14, 17, 46],
#         [11, 15, 44]],
#
#        ...,
#
#        [[18, 10, 20],
#         [18, 10, 20],
#         [19, 11, 22],
#         ...,
#         [15, 10, 10],
#         [15, 10, 10],
#         [15, 10, 10]],
#
#        [[18, 10, 20],
#         [18, 10, 20],
#         [20, 12, 23],
#         ...,
#         [15, 10, 10],
#         [15, 10, 10],
#         [15, 10, 10]],
#
#        [[18, 10, 20],
#         [19, 11, 22],
#         [22, 13, 24],
#         ...,
#         [15, 10, 10],
#         [15, 10, 10],
#         [15, 10, 10]]], dtype=uint8)

# %%
image=cv2.imread(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")
# cv2.imshow('Benzamin',image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
image
# Out:
# array([[[19, 12, 13],
#         [19, 12, 13],
#         [19, 12, 13],
#         ...,
#         [16, 20, 49],
#         [14, 17, 46],
#         [11, 15, 44]],
#
#        [[19, 12, 13],
#         [19, 12, 13],
#         [19, 12, 13],
#         ...,
#         [16, 20, 49],
#         [14, 17, 46],
#         [11, 15, 44]],
#
#        [[19, 12, 13],
#         [19, 12, 13],
#         [19, 12, 13],
#         ...,
#         [16, 20, 49],
#         [14, 17, 46],
#         [11, 15, 44]],
#
#        ...,
#
#        [[18, 10, 20],
#         [18, 10, 20],
#         [19, 11, 22],
#         ...,
#         [15, 10, 10],
#         [15, 10, 10],
#         [15, 10, 10]],
#
#        [[18, 10, 20],
#         [18, 10, 20],
#         [20, 12, 23],
#         ...,
#         [15, 10, 10],
#         [15, 10, 10],
#         [15, 10, 10]],
#
#        [[18, 10, 20],
#         [19, 11, 22],
#         [22, 13, 24],
#         ...,
#         [15, 10, 10],
#         [15, 10, 10],
#         [15, 10, 10]]], dtype=uint8)

# %%
## ALl together
import cv2
image=cv2.imread(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")
cv2.imshow('Benzamin',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(image)
# Out:
# numpy.ndarray

# %% [markdown]
# **Method:-2**
# - using google colab notebook
# - Run below codes in Google colab only

# %%
# from google.colab.patches import cv2_imshow
# import cv2
# image=cv2.imread('content/Benjamin-Franklin.webp')
# cv2_imshow(image)

# %% [markdown]
# **Method-3**

# %% [markdown]
# - using pillow package

# %%
## ======== by using pillow it will open in another window=========
from PIL import Image
image=Image.open(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")
image.show()    # open in new window

# %%
#========= remove the show it will open in same notebook ==============
from PIL import Image
image=Image.open(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")
image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=400x300>

# %%
type(image)
# Out:
# PIL.WebPImagePlugin.WebPImageFile

# %% [markdown]
# **Method:-4**
#
# - open using matplotlib

# %%
# ================Read the image using pillow and open the image using matplotlib ===================
import matplotlib.pyplot as plt
from PIL import Image
image=Image.open(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")
# open the image using matplotlib
plt.imshow(image)
plt.show()

# %%
# ================== Read the image using pillow and open by using matplotlib============
import matplotlib.pyplot as plt
import cv2
# read the image using open cv or using pillow
image=cv2.imread(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")
# oepn the  image using matplotlib
plt.imshow(image)

# =================Read the image using Pillow and open the image using matplotlib==============
import matplotlib.pyplot as plt
from PIL import Image
image=Image.open(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")

# %% [markdown]
# **writing Images**

# %%
import cv2
image=cv2.imread(r"C:\Users\hp\OneDrive\Desktop\Benzamin\Benjamin-Franklin.webp")
cv2.imwrite('output.jpg', image)
cv2.imwrite('output.png', image)
# Out:
# True
